# %% [markdown]
# **1. Create Project Structure**

# %%
# !mkdir AI_Learning_Project

# %%
# !cd AI_Learning_Project

# %%
# !pwd
# Out:
# /content

# %%
# !cd / content
# Out:
# /bin/bash: line 1: cd: too many arguments

# %%
# !mkdir  AI_Learning_Project/datasets

# %%
# !mkdir  AI_Learning_Project/notebooks/

# %%
# !mkdir  AI_Learning_Project/models/

# %%
# !mkdir  AI_Learning_Project/outputs/

# %%
# !mkdir  AI_Learning_Project/scripts/

# %%
# !mkdir  AI_Learning_Project/images/

# %%
# !mkdir  AI_Learning_Projec/docs
# Out:
# mkdir: cannot create directory ‘AI_Learning_Projec/docs’: No such file or directory

# %%
# !ls AI_Learning_Project
# Out:
# datasets  images  models  notebooks  outputs  scripts

# %%
# !cd AI_Learning_Project/datasets

# %%
# !pwd
# Out:
# /content

# %%
# !touch AI_Learning_Project/datasets/student.csv

# %%
# !cd AI_Learning_Project/notebooks/

# %%
# !pwd
# Out:
# /content

# %%
# !touch AI_Learning_Project/notebooks/notes.txt

# %%
# !cd AI_Learning_Project/models/

# %%
# !pwd
# Out:
# /content

# %%
# !touch AI_Learning_Project/models/model.txt

# %%
# !cd AI_Learning_Project/scripts/

# %%
# !pwd
# Out:
# /content

# %%
# !touch AI_Learning_Project/scripts/train.py

# %%
# !cd AI_Learning_Project/docs/
# Out:
# /bin/bash: line 1: cd: AI_Learning_Project/docs/: No such file or directory

# %%
# !pwd
# Out:
# /content

# %%
# !touch AI_Learning_Project/docs/guide.txt
# Out:
# touch: cannot touch 'AI_Learning_Project/docs/guide.txt': No such file or directory

# %%
# !touch AI_Learning_Project/docs/README.txt
# Out:
# touch: cannot touch 'AI_Learning_Project/docs/README.txt': No such file or directory

# %%
# !cd AI_Learning_Project/

# %%
# !pwd
# Out:
# /content

# %%
# !touch AI_Learning_Project/requirements.txt

# %%
# !ls -R
# Out:
# .:
# AI_Learning_Project  docs  README.md  student.csv
#
# ./AI_Learning_Project:
# datasets  images  models  notebooks  outputs  requirements.txt	scripts
#
# ./AI_Learning_Project/datasets:
# student.csv
#
# ./AI_Learning_Project/images:
#
# ./AI_Learning_Project/models:
# model.txt
#
# ./AI_Learning_Project/notebooks:
# notes.txt
#
# ./AI_Learning_Project/outputs:
#
# ./AI_Learning_Project/scripts:
# train.py

# %% [markdown]
# **3. Add Content**

# %%
# !echo AI_Learning_Project>README.md

# %%
# !echo "Project Name:AI_Learning_Project">README.md
# !echo "student Name:Tehmina younas">> README.md
# !echo "Roll NO:">> README.md
# !echo "Brief project description:This is my First AI and Machine Learning project which can we make the varius project structure by using Linux Command in Google Colab notebook and make the Students Table sheet as student.csv and practice all the other command that mention it on.">> README.md

# %%
# !cat README.md
# Out:
# Project Name:AI_Learning_Project
# student Name:Tehmina younas
# Roll NO:
# Brief project description:This is my First AI and Machine Learning project which can we make the varius project structure by using Linux Command in Google Colab notebook and make the Students Table sheet as student.csv and practice all the other command that mention it on.

# %%
# !touch README.md

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# **4. Create a Sample Dataset**

# %%
# !ls
# Out:
# AI_Learning_Project  README.md	sample_data

# %%
# !file README.md
# Out:
# README.md: empty

# %%
# !echo "ID , NAME ,AGE">student.csv
# !echo "1, Sara ,87">>student.csv
# !echo "2, Bareera ,67">>student.csv
# !echo "3, Mahnoor ,88">>student.csv
# !echo "4, Jia ,99">>student.csv
# !echo "5, Sobia ,78">>student.csv

# %%
# !head student.csv
# Out:
# ID , NAME ,AGE
# 1, Sara ,87
# 2, Bareera ,67
# 3, Mahnoor ,88
# 4, Jia ,99
# 5, Sobia ,78

# %% [markdown]
# **5. Demonstrate Linux Commands**

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# AI_Learning_Project  sample_data  Tehmina
# README.md	     student.csv  Tehminayounas

# %%
# !cat README.md
# Out:
# Project Name:AI_Learning_Project
# student Name:Tehmina younas
# Roll NO:
# Brief project description:This is my First AI and Machine Learning project which can we make the varius project structure by using Linux Command in Google Colab notebook and make the Students Table sheet as student.csv and practice all the other command that mention it on.

# %%
# !head student.csv
# Out:
# ID , NAME ,AGE
# 1, Sara ,87
# 2, Bareera ,67
# 3, Mahnoor ,88
# 4, Jia ,99
# 5, Sobia ,78

# %%
# !file student.csv
# Out:
# student.csv: CSV text

# %%
# !cp README.md docs

# %%
# !mv train.py scripts
# Out:
# mv: cannot stat 'train.py': No such file or directory

# %%
# !rm model.txt
# Out:
# rm: cannot remove 'model.txt': No such file or directory
